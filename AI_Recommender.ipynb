# %%
# !pip install scikit-surprise
# Out:
# Collecting scikit-surprise
#   Downloading scikit-surprise-1.1.3.tar.gz (771 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.0/772.0 kB 7.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.3.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.11.4)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (setup.py) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.3-cp310-cp310-linux_x86_64.whl size=3163006 sha256=c1b263e8c1169f42da2ba3ce14364d1d5974b4959614685456f5360437446be4
#   Stored in directory: /root/.cache/pip/wheels/a5/ca/a8/4e28def53797fdc4363ca4af740db15a9c2f1595ebc51fb445
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise
# Successfully installed scikit-surprise-1.1.3

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from surprise import Dataset, Reader, SVD
from surprise.model_selection import train_test_split
from surprise.accuracy import rmse
from surprise.model_selection import cross_validate

# %%
df = pd.read_csv('/content/HackNiche 2.0 AI-ML PS 4 Dataset.csv')

# %%
df.head()
# Out:
#       Company  GST No        State  State Code    City               Address  \
# 0  Main Store     NaN  Maharashtra          27  Mumbai  148 B, Juhu Tara Rd,
# 1  Main Store     NaN  Maharashtra          27  Mumbai  148 B, Juhu Tara Rd,
# 2  Main Store     NaN  Maharashtra          27  Mumbai  148 B, Juhu Tara Rd,
# 3  Main Store     NaN  Maharashtra          27  Mumbai  148 B, Juhu Tara Rd,
# 4  Main Store     NaN  Maharashtra          27  Mumbai  148 B, Juhu Tara Rd,
#
#    Zip Code  PAN  CIN               Customer  ... CESS Tax Total TCS (₹)  \
# 0    400049  NaN  NaN      SHOEB FAIM SHAIKH  ...        0           0.0
# 1    400049  NaN  NaN      SHOEB FAIM SHAIKH  ...        0           NaN
# 2    400049  NaN  NaN      SHOEB FAIM SHAIKH  ...        0           NaN
# 3    400049  NaN  NaN        Bhakti Catering  ...        0           0.0
# 4    400049  NaN  NaN  Lagoon General Stores  ...        0           0.0
#
#    Discount (₹)  Delivery Charge (₹) Total Amount (₹) Invoice Total (₹)  \
# 0           0.0                  0.0           4400.0            7310.0
# 1           NaN                  NaN           2475.0               NaN
# 2           NaN                  NaN            435.0               NaN
# 3           0.0                  0.0           1650.0            1650.0
# 4           0.0                  0.0            200.0             200.0
#
#    Raw Material ID Raw Material Code Description  \
# 0         16704437               NaN         NaN
# 1         16704438               NaN         NaN
# 2         16704456               NaN         NaN
# 3         16704128               NaN         NaN
# 4         16704023               NaN         NaN
#
#                  Customer Address.1
# 0  Nalasopara, Palghar, Maharashtra
# 1         Juhu, Mumbai, Maharashtra
# 2   Vile Parle, Mumbai, Maharashtra
# 3         Juhu, Mumbai, Maharashtra
# 4       Bandra, Mumbai, Maharashtra
#
# [5 rows x 44 columns]
# Warning: Total number of columns (44) exceeds max_columns (20) limiting to first (20) columns.

# %%
df1 = df[['Raw Material', 'Category', 'Price (₹)', 'Pre Tax Amount (₹)', 'Total Amount (₹)']]
df1.head()
# Out:
#         Raw Material       Category  Price (₹)  Pre Tax Amount (₹)  \
# 0       Tiger Prawns  Meat Material     1100.0              4400.0
# 1        Surmay Fish  Meat Material      550.0              2475.0
# 2             Bombil  Meat Material      150.0               435.0
# 3  Chapati For Staff        Grocery        5.5              1650.0
# 4       Oreo Biscuit        Grocery       10.0               200.0
#
#    Total Amount (₹)
# 0            4400.0
# 1            2475.0
# 2             435.0
# 3            1650.0
# 4             200.0

# %%
df2 = pd.read_csv('/content/sales_dump.csv')
df2.head()
# Out:
#          Date            Timestamp Invoice No. Payment Type Order Type  \
# 0  2024-01-22  2024-01-22 23:57:19       21006         CARD    Dine In
# 1  2024-01-22  2024-01-22 23:57:19       21006         CARD    Dine In
# 2  2024-01-22  2024-01-22 23:57:19       21006         CARD    Dine In
# 3  2024-01-22  2024-01-22 23:57:19       21006         CARD    Dine In
# 4  2024-01-22  2024-01-22 23:43:28       21005         CARD    Dine In
#
#      Area                             Item Name   Price  Qty.  Sub Total  ...  \
# 0  Dining                             Aeropress  247.62     1     247.62  ...
# 1  Dining               Iced Americano (350 ML)  176.19     1     176.19  ...
# 2  Dining  Add On Syrup (Add On Tiramisu Syrup)   47.62     1      47.62  ...
# 3  Dining                        Baked Vada Pav   76.19     2     152.38  ...
# 4  Dining    South Indian Filter Kaapi (250 ML)  176.19     2     352.38  ...
#
#        Assign To  Non Taxable  CGST Rate CGST Amount SGST Rate SGST Amount  \
# 0            NaN          0.0        2.5        6.19       2.5        6.19
# 1            NaN          0.0        2.5        4.40       2.5        4.40
# 2            NaN          0.0        2.5        1.19       2.5        1.19
# 3            NaN          0.0        2.5        3.81       2.5        3.81
# 4  NARESH RATHOD          0.0        2.5        8.81       2.5        8.81
#
#    VAT Rate VAT Amount Service Charge Rate  Service Charge Amount
# 0        10      24.76                 NaN                    NaN
# 1        10      17.62                 NaN                    NaN
# 2        10       4.76                 NaN                    NaN
# 3        10      15.24                 NaN                    NaN
# 4        10      35.24                 NaN                    NaN
#
# [5 rows x 34 columns]

# %%
df3 = df[['Item Name', 'Price', 'Qty.', 'Sub Total', 'Discount', 'Tax', 'Final Total', 'Category']]
df3.head()
# Out:
#                               Item Name   Price  Qty.  Sub Total  Discount  \
# 0                             Aeropress  247.62     1     247.62       0.0
# 1               Iced Americano (350 ML)  176.19     1     176.19       0.0
# 2  Add On Syrup (Add On Tiramisu Syrup)   47.62     1      47.62       0.0
# 3                        Baked Vada Pav   76.19     2     152.38       0.0
# 4    South Indian Filter Kaapi (250 ML)  176.19     2     352.38       0.0
#
#      Tax  Final Total        Category
# 0  37.14       284.76     Manual Brew
# 1  26.42       202.61     Cold Coffee
# 2   7.14        54.76  Extra Toppings
# 3  22.86       175.24       Food Menu
# 4  52.86       405.24      Hot Coffee

# %%
from sklearn.preprocessing import MinMaxScaler
df3 = df[['Item Name', 'Price', 'Qty.', 'Sub Total', 'Discount', 'Tax', 'Final Total', 'Category']]

scaler = MinMaxScaler()
normalized_data = scaler.fit_transform(df3[['Qty.', 'Sub Total', 'Discount', 'Tax']])

weights = {'Qty.': 0.4, 'Sub Total': 0.3, 'Discount': 0.2, 'Tax': 0.1}

weighted_scores = (normalized_data * list(weights.values())).sum(axis=1)
df3['Weighted Score'] = weighted_scores

recommended_items = df3.sort_values(by='Weighted Score', ascending=False).head(5)

print("Top 5 recommended items:")
print(recommended_items[['Item Name', 'Weighted Score']])
# Out:
# Top 5 recommended items:
#                                 Item Name  Weighted Score
# 76                         Baked Vada Pav        0.666681
# 461                   Vietnamese (350 ML)        0.466487
# 541               Classic Frappe (350 ML)        0.456513
# 672                   Cafe Latte (250 ML)        0.447623
# 408  Madagascar Chocochip Frappe (350 ML)        0.387878
# <ipython-input-28-2e75c406d377>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Weighted Score'] = weighted_scores

# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
standardized_data = scaler.fit_transform(df3[['Price', 'Qty.', 'Sub Total', 'Discount', 'Tax', 'Final Total']])
item_sim_matrix = cosine_similarity(standardized_data)
def get_recommendations(item_name, n=5):
    # Find the index of the given item
    item_index = df3.index[df3['Item Name'] == item_name].tolist()
    if not item_index:
        print("Item not found in the dataset.")
        return []
    item_sim_scores = list(enumerate(item_sim_matrix[item_index[0]]))
    item_sim_scores = sorted(item_sim_scores, key=lambda x: x[1], reverse=True)
    sim_item_indices = [i for i, _ in item_sim_scores[1:n+1]]
    recommendations = df3['Item Name'].iloc[sim_item_indices].tolist()

    return recommendations

# Example usage:
item_name = 'Aeropress'  # Example item name
recommendations = get_recommendations(item_name)
print("Top 5 recommendations for item", item_name, ":", recommendations)
# Out:
# Top 5 recommendations for item Aeropress : ['Pour Over', 'Hot Chocolate (250 ML)', 'Hot Chocolate (250 ML)', 'Hot Chocolate (250 ML)', 'Hot Chocolate (250 ML)']
